# %% [markdown]
# '''
# Use the asyncio library. So async funct with await
# ''''

# %%
import asyncio

def fare_start():
    pass

def fare_stop():
    pass

def fare_pause():
    pass

#coroutine function, can pause
async def taximeter():
    fare_start()
    await fare_pause
    fare_stop()

# %% [markdown]
# '''
# So, create a function for how the taximeter will start, another (fare_pause), for when it is running but pause, and the last for when it finally stops. I need to think about it
# '''
